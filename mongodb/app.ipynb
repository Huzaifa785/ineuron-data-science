# %%
from pymongo import MongoClient

# %%
uri = "mongodb+srv://huzaifa:huzaifa123@ineuron-mongodb-cluster.dyvmrfq.mongodb.net/?retryWrites=true&w=majority"

# %%
client = MongoClient(uri)

# %%
# Send a ping to confirm connection
try:
    client.admin.command('ping')
    print("Pinged MongoDB Atlas at", uri)
except Exception as e:
    print (e)
# Out:
# Pinged MongoDB Atlas at mongodb+srv://huzaifa:huzaifa123@ineuron-mongodb-cluster.dyvmrfq.mongodb.net/?retryWrites=true&w=majority

# %%
my_db = client["mydatabase"]

# %%
my_collection = mydb["mycollection"]

# %%
first_record = {"name": "Huzaifa", "email": "huzaifa.coder785@gmail.com", "designation": "Data Scientist"}

# %%
my_collection.insert_one(first_record)

# %%
multiple_records = [
    {"name": "John", "email": "john@gmail.com", "designation": "Data Engineer"},
    {"name": "Jane", "email": "jane@gmail.com", "designation": "UI/UX Designer"},
    {"name": "Tom", "email": "tom@gmail.com", "designation": "Frontend Developer"},
    {"name": "Tim", "email": "tim@gmail.com", "designation": "Product Manager"}
]

# %%
x = my_collection.insert_many(multiple_records)

# %%
x.inserted_ids
# Out:
# [ObjectId('64eae6fe1b63234bd5b6a2c9'),
#  ObjectId('64eae6fe1b63234bd5b6a2ca'),
#  ObjectId('64eae6fe1b63234bd5b6a2cb'),
#  ObjectId('64eae6fe1b63234bd5b6a2cc')]

# %%
# custom id
multiple_records = [
    {"_id": 1, "name": "Harry", "email": "harry@gmail.com", "designation": "Software Tester"},
    {"_id": 2, "name": "Jenkins", "email": "jenkins@gmail.com", "designation": "Business Analyst"},
]

# %%
my_collection.insert_many(multiple_records)

# %%
my_collection.find_one()
# Out:
# {'_id': ObjectId('64eae58d1b63234bd5b6a2c4'),
#  'name': 'Huzaifa',
#  'email': 'huzaifa.coder785@gmail.com',
#  'designation': 'Data Scientist'}

# %%
for i in my_collection.find():
    print(i)
# Out:
# {'_id': ObjectId('64eae58d1b63234bd5b6a2c4'), 'name': 'Huzaifa', 'email': 'huzaifa.coder785@gmail.com', 'designation': 'Data Scientist'}
# {'_id': ObjectId('64eae6fe1b63234bd5b6a2c9'), 'name': 'John', 'email': 'john@gmail.com', 'designation': 'Data Engineer'}
# {'_id': ObjectId('64eae6fe1b63234bd5b6a2ca'), 'name': 'Jane', 'email': 'jane@gmail.com', 'designation': 'UI/UX Designer'}
# {'_id': ObjectId('64eae6fe1b63234bd5b6a2cb'), 'name': 'Tom', 'email': 'tom@gmail.com', 'designation': 'Frontend Developer'}
# {'_id': ObjectId('64eae6fe1b63234bd5b6a2cc'), 'name': 'Tim', 'email': 'tim@gmail.com', 'designation': 'Product Manager'}
# {'_id': 1, 'name': 'Harry', 'email': 'harry@gmail.com', 'designation': 'Software Tester'}
# {'_id': 2, 'name': 'Jenkins', 'email': 'jenkins@gmail.com', 'designation': 'Business Analyst'}

# %%
# finding based on condition
my_collection.find_one({"_id": 1})
# Out:
# {'_id': 1,
#  'name': 'Harry',
#  'email': 'harry@gmail.com',
#  'designation': 'Software Tester'}

# %%
my_collection.find_one({"designation": "Data Scientist"})
# Out:
# {'_id': ObjectId('64eae58d1b63234bd5b6a2c4'),
#  'name': 'Huzaifa',
#  'email': 'huzaifa.coder785@gmail.com',
#  'designation': 'Data Scientist'}

# %%
my_collection.insert_one({"name": "Ken", "email": "ken@gmail.com", "designation": "Data Engineer"},)

# %%
for i in my_collection.find({"designation": "Data Engineer"}):
    print(i)
# Out:
# {'_id': ObjectId('64eae6fe1b63234bd5b6a2c9'), 'name': 'John', 'email': 'john@gmail.com', 'designation': 'Data Engineer'}
# {'_id': ObjectId('64eaeae11b63234bd5b6a2cd'), 'name': 'Ken', 'email': 'ken@gmail.com', 'designation': 'Data Engineer'}

# %%
for i in my_collection.find().sort("name"):
    print(i)
# Out:
# {'_id': 1, 'name': 'Harry', 'email': 'harry@gmail.com', 'designation': 'Software Tester'}
# {'_id': ObjectId('64eae58d1b63234bd5b6a2c4'), 'name': 'Huzaifa', 'email': 'huzaifa.coder785@gmail.com', 'designation': 'Data Scientist'}
# {'_id': ObjectId('64eae6fe1b63234bd5b6a2ca'), 'name': 'Jane', 'email': 'jane@gmail.com', 'designation': 'UI/UX Designer'}
# {'_id': 2, 'name': 'Jenkins', 'email': 'jenkins@gmail.com', 'designation': 'Business Analyst'}
# {'_id': ObjectId('64eae6fe1b63234bd5b6a2c9'), 'name': 'John', 'email': 'john@gmail.com', 'designation': 'Data Engineer'}
# {'_id': ObjectId('64eae6fe1b63234bd5b6a2cc'), 'name': 'Tim', 'email': 'tim@gmail.com', 'designation': 'Product Manager'}
# {'_id': ObjectId('64eae6fe1b63234bd5b6a2cb'), 'name': 'Tom', 'email': 'tom@gmail.com', 'designation': 'Frontend Developer'}

# %%
for i in my_collection.find().sort("name", -1):
    print(i)
# Out:
# {'_id': ObjectId('64eae6fe1b63234bd5b6a2cb'), 'name': 'Tom', 'email': 'tom@gmail.com', 'designation': 'Frontend Developer'}
# {'_id': ObjectId('64eae6fe1b63234bd5b6a2cc'), 'name': 'Tim', 'email': 'tim@gmail.com', 'designation': 'Product Manager'}
# {'_id': ObjectId('64eae6fe1b63234bd5b6a2c9'), 'name': 'John', 'email': 'john@gmail.com', 'designation': 'Data Engineer'}
# {'_id': 2, 'name': 'Jenkins', 'email': 'jenkins@gmail.com', 'designation': 'Business Analyst'}
# {'_id': ObjectId('64eae6fe1b63234bd5b6a2ca'), 'name': 'Jane', 'email': 'jane@gmail.com', 'designation': 'UI/UX Designer'}
# {'_id': ObjectId('64eae58d1b63234bd5b6a2c4'), 'name': 'Huzaifa', 'email': 'huzaifa.coder785@gmail.com', 'designation': 'Data Scientist'}
# {'_id': 1, 'name': 'Harry', 'email': 'harry@gmail.com', 'designation': 'Software Tester'}

# %%
my_collection.delete_one({"name": "Huzaifa"})

# %%
for i in my_collection.find():
    print(i)
# Out:
# {'_id': ObjectId('64eae6fe1b63234bd5b6a2c9'), 'name': 'John', 'email': 'john@gmail.com', 'designation': 'Data Engineer'}
# {'_id': ObjectId('64eae6fe1b63234bd5b6a2ca'), 'name': 'Jane', 'email': 'jane@gmail.com', 'designation': 'UI/UX Designer'}
# {'_id': ObjectId('64eae6fe1b63234bd5b6a2cb'), 'name': 'Tom', 'email': 'tom@gmail.com', 'designation': 'Frontend Developer'}
# {'_id': ObjectId('64eae6fe1b63234bd5b6a2cc'), 'name': 'Tim', 'email': 'tim@gmail.com', 'designation': 'Product Manager'}
# {'_id': 1, 'name': 'Harry', 'email': 'harry@gmail.com', 'designation': 'Software Tester'}
# {'_id': 2, 'name': 'Jenkins', 'email': 'jenkins@gmail.com', 'designation': 'Business Analyst'}
# {'_id': ObjectId('64eaeae11b63234bd5b6a2cd'), 'name': 'Ken', 'email': 'ken@gmail.com', 'designation': 'Data Engineer'}

# %%
for i in my_collection.find().limit(3):
    print(i)
# Out:
# {'_id': ObjectId('64eae6fe1b63234bd5b6a2c9'), 'name': 'John', 'email': 'john@gmail.com', 'designation': 'Data Engineer'}
# {'_id': ObjectId('64eae6fe1b63234bd5b6a2ca'), 'name': 'Jane', 'email': 'jane@gmail.com', 'designation': 'UI/UX Designer'}
# {'_id': ObjectId('64eae6fe1b63234bd5b6a2cb'), 'name': 'Tom', 'email': 'tom@gmail.com', 'designation': 'Frontend Developer'}

# %%
current_value = {"name": "Ken"}
new_value = {"$set": {"name": "Kenny"}}

# %%
my_collection.update_one(current_value, new_value)

# %%
for i in my_collection.find():
    print(i)
# Out:
# {'_id': ObjectId('64eae6fe1b63234bd5b6a2c9'), 'name': 'John', 'email': 'john@gmail.com', 'designation': 'Data Engineer'}
# {'_id': ObjectId('64eae6fe1b63234bd5b6a2ca'), 'name': 'Jane', 'email': 'jane@gmail.com', 'designation': 'UI/UX Designer'}
# {'_id': ObjectId('64eae6fe1b63234bd5b6a2cb'), 'name': 'Tom', 'email': 'tom@gmail.com', 'designation': 'Frontend Developer'}
# {'_id': ObjectId('64eae6fe1b63234bd5b6a2cc'), 'name': 'Tim', 'email': 'tim@gmail.com', 'designation': 'Product Manager'}
# {'_id': 1, 'name': 'Harry', 'email': 'harry@gmail.com', 'designation': 'Software Tester'}
# {'_id': 2, 'name': 'Jenkins', 'email': 'jenkins@gmail.com', 'designation': 'Business Analyst'}
# {'_id': ObjectId('64eaeae11b63234bd5b6a2cd'), 'name': 'Kenny', 'email': 'ken@gmail.com', 'designation': 'Data Engineer'}

# %%
multiple_records = [
    {"name": "Ken", "email": "ken@gmail.com", "designation": "Data Scientist", "salary": 100000},
    {"name": "Nas", "email": "nas@gmail.com", "designation": "Software Engineer", "salary": 80000},
]

# %%
my_collection.insert_many(multiple_records)

# %%
for i in my_collection.find({"salary": {"$lt": 90000}}):
    print(i)
# Out:
# {'_id': ObjectId('64eaee7e1b63234bd5b6a2cf'), 'name': 'Nas', 'email': 'nas@gmail.com', 'designation': 'Software Engineer', 'salary': 80000}

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/sunnysavita10/Statistics-With-Python-TheCompleteGuide/main/clead_google_playstore_data")

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510   8700.0   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967   2800.0    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0      4.0.3
# ...

# %%
len(df.columns)
# Out:
# 16

# %%
my_db = client["mydatabase"]

# %%
google_playstore_collection = my_db["google_playstore_collection"]

# %%
import json
json.loads(df.T.to_json())
# Out:
# {'0': {'App': 'Photo Editor & Candy Camera & Grid & ScrapBook',
#   'Category': 'ART_AND_DESIGN',
#   'Rating': 4.1,
#   'Reviews': 159,
#   'Size': 19000.0,
#   'Installs': 10000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content Rating': 'Everyone',
#   'Genres': 'Art & Design',
#   'Last Updated': '2018-01-07',
#   'Current Ver': '1.0.0',
#   'Android Ver': '4.0.3 ',
#   'day': 7,
#   'month': 1,
#   'year': 2018},
#  '1': {'App': 'Coloring book moana',
#   'Category': 'ART_AND_DESIGN',
#   'Rating': 3.9,
#   'Reviews': 967,
#   'Size': 14000.0,
#   'Installs': 500000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content Rating': 'Everyone',
#   'Genres': 'Art & Design;Pretend Play',
#   'Last Updated': '2018-01-15',
#   'Current Ver': '2.0.0',
#   'Android Ver': '4.0.3 ',
#   'day': 15,
#   'month': 1,
#   'year': 2018},
#  '2': {'App': 'U Launcher Lite – FREE Live Cool Themes, Hide Apps',
#   'Category': 'ART_AND_DESIGN',
#   'Rating': 4.7,
#   'Reviews': 87510,
# ...

# %%
csv_data = list(json.loads(df.T.to_json()).values())

# %%
google_playstore_collection.insert_many(csv_data)
