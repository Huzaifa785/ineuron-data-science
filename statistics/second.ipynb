# %% [markdown]
# ## Topics covered
#
# 1. Outliers
# 2. Q-Q Plot
# 3. Different types of probability distributions
# 4. Central Limit Theorem
# 5. Visualizations

# %%
data = [23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
data
# Out:
# [23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
data_copy = data.copy()

# %%
import seaborn as sns
sns.histplot(data_copy, kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
data_copy.sort()

# %%
data_copy
# Out:
# [12, 23, 24, 32, 32, 32, 43, 45, 45, 56, 67]

# %%
data_copy.append(179)

# %%
data_copy.append(210)

# %%
data_copy.append(290)

# %%
sns.histplot(data_copy, kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
data
# Out:
# [23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
data_copy # right skewed data
# Out:
# [12, 23, 24, 32, 32, 32, 43, 45, 45, 56, 67, 179, 210, 290]

# %%
data_copy_2 = data.copy()

# %%
data_copy_2
# Out:
# [23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
data_copy_2.insert(0, -10)

# %%
data_copy_2
# Out:
# [-10, 23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
data_copy_2.insert(0, -75)

# %%
data_copy_2
# Out:
# [-75, -10, 23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
sns.histplot(data_copy_2, kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
import pandas as pd
df = pd.read_csv("iris.csv")

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df["petal_length"]
# Out:
# 0      1.4
# 1      1.4
# 2      1.3
# 3      1.5
# 4      1.4
#       ...
# 145    5.2
# 146    5.0
# 147    5.2
# 148    5.4
# 149    5.1
# Name: petal_length, Length: 150, dtype: float64

# %%
sns.histplot(df["sepal_length"], kde=True)
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
sns.histplot(df["sepal_width"], kde=True)
# Out:
# <Axes: xlabel='sepal_width', ylabel='Count'>

# %%
sns.histplot(df["petal_length"], kde=True)
# Out:
# <Axes: xlabel='petal_length', ylabel='Count'>

# %%
sns.histplot(df["petal_width"], kde=True)
# Out:
# <Axes: xlabel='petal_width', ylabel='Count'>

# %%
import numpy as np

mu = 0.5
sigma = 0.2

normal_distributed_data = np.random.normal(mu, sigma, 1000)

# %%
normal_distributed_data
# Out:
# array([ 0.32349307,  0.49719769,  0.65255704,  0.67854251,  0.45527944,
#         0.44341106,  0.92422434,  0.21918686,  0.2849553 ,  0.13321147,
#         0.52460432,  0.66720241,  0.57456416,  0.54567423,  0.4545221 ,
#         0.22207968,  0.32334499,  0.35489049,  0.75832173,  0.31992381,
#         0.82129761,  0.50078259,  0.56382786,  0.32392881,  0.56934539,
#         0.40240713,  0.47761966,  0.31758778,  0.51062364,  0.69423127,
#         0.52179208,  0.57868984,  0.6730247 ,  0.50403708,  0.4572519 ,
#         0.67437124,  0.52862336,  0.72644163,  0.23627827,  0.83141329,
#         0.33830376,  1.06382461,  0.61299559,  0.28071915,  0.7469624 ,
#         0.38749962,  0.71125011,  0.56967133,  0.79083819,  0.83274115,
#         0.51122623,  0.8482496 ,  0.61945738,  0.37094682,  0.45353592,
#         0.30229061,  0.92909936,  0.24304155,  0.67204467,  0.17059208,
#         0.66116876,  0.55858503,  0.52397035,  0.40017358,  1.02319671,
#         0.67010205,  0.51723792,  0.77703364,  0.50324663,  0.38059652,
#         0.58421451,  0.648264  ,  0.39916817,  0.8094428 ,  0.50837523,
#         0.30768568,  0.45913662,  0.27674627,  0.39772864,  0.49001262,
#         0.5712834 ,  0.49394571,  0.37239579,  0.28385636,  0.25293968,
#         0.66200804,  0.34367219,  0.88482988,  0.60835922,  0.4516127 ,
#         0.36994141,  0.5241403 ,  0.63496383,  0.28352895,  0.79238943,
#         0.20023322,  0.50286589,  0.11728728,  0.62470805,  0.81676226,
#         0.51094687,  0.50504622,  0.66679469,  0.38438427,  0.30637977,
#         0.10359441,  0.39275294,  0.63342041,  0.446195  ,  0.3692334 ,
#         0.4154513 ,  0.6923166 ,  0.69024169,  0.37635925,  0.41819269,
#         0.78686962,  0.57418693,  0.62738194,  0.45296023,  0.64979867,
#         0.69857719,  0.46478962,  0.48882478,  0.5868985 ,  0.58866248,
#         0.6839753 ,  0.60668749,  0.37881338,  0.39523525,  0.47305799,
#         0.37123079,  0.64432104,  0.78049599,  0.30189156,  0.35318469,
#         0.59908273,  0.3983891 ,  0.4597997 ,  0.4466729 ,  0.66446672,
#         0.68899933,  0.57339869,  0.40900937,  0.46109595,  0.39514702,
#         0.92034575,  0.32499312,  0.49457269,  0.08773294,  0.34048408,
#         0.40610814,  0.5869772 ,  0.256307  ,  0.23543567,  0.40416988,
#         0.66370418,  0.52562526,  0.57455513,  0.51305806,  0.87181961,
#         0.42426786,  0.50414797,  0.58854067,  0.32893231,  0.15173938,
#         0.51985189,  0.28233558,  0.713172  ,  0.22242313,  0.13674276])

# %%
sns.histplot(normal_distributed_data, kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
mu = 3
sigma = 1

lognormal_distributed_data = np.random.lognormal(mu, sigma, 1000)

# %%
sns.histplot(lognormal_distributed_data, kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(np.log(lognormal_distributed_data), kde=True)
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# ## q-q plot (Quantile Quantile Plot)
#
# why we use q-q plot
#
# to check whether our data is normal or not

# %%
import matplotlib.pyplot as plt
import scipy.stats as stat
import pylab

def plot_data(sample):
    plt.figure(figsize=(10, 6))
    plt.subplot(1, 2, 1)

    sns.histplot(sample, kde=True)
    plt.subplot(1, 2, 2)
    stat.probplot(sample, dist="norm", plot=pylab)

    plt.show()

# %%
plot_data(lognormal_distributed_data)

# %%
plot_data(np.log(lognormal_distributed_data))

# %% [markdown]
# ### probability distribution function
#
# 1. probability mass function (discrete)
# - uniform
# - bernouli
# - binomial dist.
# - poisson
#
# 2. probability density function (continous)
# - uniform
# - normal (SND)
# - lognormal
# - power law
# - pareto

# %%
from numpy import random

uniform_data = random.uniform(size=500)

# %%
uniform_data # continuous values
# Out:
# array([5.20811216e-01, 4.01534019e-01, 7.41421084e-01, 5.13670223e-01,
#        4.63778698e-01, 1.74597318e-01, 3.22637651e-01, 5.98573158e-01,
#        8.90452852e-01, 9.66487738e-01, 2.91705846e-01, 5.29669789e-01,
#        6.76697290e-01, 1.37311436e-01, 9.52395361e-01, 9.02254487e-01,
#        2.07157746e-01, 1.18545213e-01, 1.19163398e-01, 5.66613230e-01,
#        4.52032932e-01, 2.18200097e-01, 7.70761539e-01, 2.64747434e-01,
#        8.80766958e-02, 5.05480925e-01, 9.10369682e-01, 5.94074611e-01,
#        2.24149703e-02, 5.71894685e-01, 8.05193164e-01, 6.09308355e-01,
#        2.04130119e-01, 3.00081184e-01, 2.18970360e-01, 5.80989245e-01,
#        3.98843987e-01, 3.24787775e-01, 7.10235200e-01, 2.80113787e-01,
#        9.57408020e-01, 9.54763683e-01, 2.35199861e-01, 5.23059568e-01,
#        6.96980475e-01, 7.71608596e-01, 4.58095389e-01, 5.06645040e-01,
#        8.98998268e-01, 9.44531738e-01, 3.01947742e-01, 5.96535828e-01,
#        3.25764595e-01, 6.78942351e-01, 4.08798919e-01, 3.21400202e-02,
#        1.41459709e-01, 2.95984816e-01, 2.53626350e-01, 6.55949849e-01,
#        6.50344353e-01, 9.83858673e-01, 8.44826088e-01, 7.81603165e-02,
#        2.02417668e-01, 3.29417365e-01, 1.68054177e-01, 9.70519528e-01,
#        5.15219001e-01, 8.33167612e-01, 7.73793081e-03, 5.23286801e-01,
#        4.36636580e-01, 2.50610589e-01, 3.97115824e-02, 8.64122924e-01,
#        1.92652876e-01, 8.23210226e-01, 4.69049253e-01, 8.30846060e-01,
#        5.07145385e-01, 3.83131639e-01, 2.76544288e-02, 3.36111095e-02,
#        7.82203685e-02, 8.27757731e-01, 4.84304123e-01, 8.76762031e-01,
#        9.80199555e-01, 3.64487258e-02, 5.91547139e-01, 7.06918684e-01,
#        9.61884609e-01, 5.39158070e-01, 3.13914478e-01, 8.80611191e-01,
#        1.07783512e-01, 4.26664974e-01, 6.72485869e-01, 2.65495510e-01,
#        5.73165373e-01, 5.01110963e-01, 6.00894828e-01, 4.54514342e-01,
#        3.83969617e-01, 3.75319504e-01, 1.74248001e-01, 9.17895658e-01,
#        3.90882027e-01, 9.13574454e-01, 6.08723113e-01, 2.66806727e-01,
#        2.96966517e-01, 1.95594631e-01, 2.41049949e-01, 9.72464258e-01,
#        1.66431727e-01, 7.73264569e-01, 4.61389266e-01, 1.80436815e-01,
#        9.57178719e-01, 3.87479963e-01, 6.97270745e-01, 2.91428740e-01,
#        5.04249136e-01, 8.59966175e-01, 8.07889298e-02, 1.35238403e-02,
#        2.60110195e-01, 4.67635958e-01, 4.77995981e-01, 7.56423599e-01,
#        3.55327221e-01, 8.21134743e-01, 9.51107749e-01, 3.83615419e-01,
#        7.76327822e-01, 4.24744967e-02, 9.07055651e-01, 6.72454441e-01,
#        4.47063464e-01, 5.05104804e-01, 2.39016556e-02, 7.01253366e-01,
#        4.39311571e-01, 2.46842070e-01, 4.28761940e-01, 1.79901892e-01,
#        4.18316845e-01, 2.80451501e-03, 5.86936126e-01, 9.63083237e-01,
#        2.80489753e-01, 6.08925972e-01, 4.83945345e-01, 5.40584763e-01,
#        4.58549504e-01, 2.94785649e-01, 7.80057147e-01, 6.04343643e-01,
#        9.99519093e-01, 5.81667849e-01, 9.00189719e-01, 6.89319346e-01,
#        6.87730078e-01, 3.86521638e-01, 9.39833757e-01, 5.95198281e-01,
#        3.78452170e-01, 4.27431087e-01, 3.70139617e-01, 1.92050719e-01,
#        1.71873478e-01, 4.52604926e-01, 6.37162422e-01, 9.32067292e-01,
#        6.05910585e-02, 4.46355246e-01, 1.85231827e-01, 5.21879402e-01,
#        7.75266079e-02, 5.79945648e-01, 4.39325971e-02, 9.22440709e-01,
#        3.08827213e-01, 4.52762413e-01, 9.08501456e-01, 6.74534199e-01,
#        4.30301593e-01, 1.85453295e-02, 2.77366320e-01, 4.41996580e-01,
#        7.53400495e-01, 6.16455803e-01, 4.98972621e-01, 3.65109619e-01,
#        1.53136893e-01, 7.43990903e-02, 3.26663932e-01, 6.22712040e-01])

# %%
sns.displot(uniform_data, kind="kde")

# %%
sns.histplot(np.random.randint(1, 8, size=800)) # discrete_values | uniform data
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# #### bernouli distribution

# %%
p = 0.3
sample_size = 1000

bernouli_data = np.random.choice([0, 1], size=sample_size, p=[1-p, p])

sns.histplot(bernouli_data, bins=2, kde=False, color="blue")
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# #### binomial dist.

# %%
no_of_trials = 10
probability = 0.6

binomial_data = np.random.binomial(no_of_trials, probability, 10000)

# %%
sns.displot(binomial_data, kind="kde")

# %% [markdown]
# #### poisson dist.

# %%
poisson_data = np.random.poisson(lam=5, size=1000)

ax = sns.histplot(poisson_data, kde=False, color="blue")

ax.set(xlabel="Poisson Distribution", ylabel="Frequency")

plt.show()

# %% [markdown]
# ### Central Limit Theorem
#
# **Suppose you have a population with any shape of probability distribution (not necessarily normal), and you draw random samples of a fixed size from this population. As the sample size increases, the distribution of the sample means approaches a normal distribution, regardless of the shape of the original population distribution.**

# %%
population = np.random.randint(10, 20, 50)

# %%
population
# Out:
# array([13, 19, 14, 18, 13, 18, 10, 14, 13, 16, 17, 12, 19, 14, 14, 18, 12,
#        16, 17, 17, 15, 11, 14, 18, 12, 11, 15, 16, 10, 11, 17, 13, 18, 12,
#        13, 16, 19, 10, 12, 16, 13, 10, 13, 10, 13, 13, 14, 12, 11, 12])

# %%
np.mean(population)
# Out:
# 14.08

# %%
np.median(population)
# Out:
# 13.5

# %%
from statistics import mode

mode(population)
# Out:
# 13

# %%
# random sample from the population
sample = np.random.choice(population, 20)

# %%
print(f"Mean of the sample: {np.mean(sample)}")
print(f"Median of the sample: {np.median(sample)}")
print(f"Mode of the sample: {mode(sample)}")
# Out:
# Mean of the sample: 14.85
# Median of the sample: 14.5
# Mode of the sample: 18

# %%
sample1 = np.random.choice(population, 20)
sample2 = np.random.choice(population, 20)
sample3 = np.random.choice(population, 20)
sample4 = np.random.choice(population, 20)

# %%
print(sample1)
print(60 * "=")
print(sample2)
print(60 * "=")
print(sample3)
print(60 * "=")
print(sample4)
print(60 * "=")
# Out:
# [11 12 15 11 16 18 11 11 18 10 14 15 14 12 10 16 14 19 12 16]
# ============================================================
# [10 17 18 13 12 17 12 17 13 16 13 13 10 13 14 13 13 13 13 16]
# ============================================================
# [12 12 19 13 16 12 11 18 13 15 13 10 11 14 14 14 17 14 15 17]
# ============================================================
# [10 12 15 14 19 14 13 10 17 10 10 13 18 18 10 12 19 15 14 14]
# ============================================================

# %%
mean_of_the_sample = []

all_samples = [sample1, sample2, sample3, sample4]

for sample in all_samples:
    print(np.mean(sample))
    mean_of_the_sample.append(np.mean(sample))
# Out:
# 13.75
# 13.8
# 14.0
# 13.85

# %%
mean_of_the_sample
# Out:
# [13.75, 13.8, 14.0, 13.85]

# %%
population = np.random.binomial(10, 0.5, 10000)

# %%
population
# Out:
# array([4, 5, 2, ..., 2, 4, 4])

# %%
len(population)
# Out:
# 10000

# %%
sns.displot(population, kind="kde")

# %% [markdown]
# Suppose you have a population with any shape of probability distribution (not necessarily normal), and you draw random samples **(at least 30)** of a fixed size(in our case i took 3000 initially) from this population. As the sample size increases **(it might be anything and take as much as data)**, the distribution of the sample means approaches a normal distribution, regardless of the shape of the original population distribution.

# %%
len(population)
# Out:
# 10000

# %%
size = int(len(population) * 0.40)
size
# Out:
# 4000

# %%
sample_mean = []

for i in range(1, 31):
    sample = np.random.choice(population, size=size)
    sample_mean.append(np.mean(sample))

# %%
sample_mean
# Out:
# [4.993,
#  4.9975,
#  5.015,
#  4.9855,
#  4.98175,
#  4.98525,
#  4.99525,
#  4.9755,
#  5.02275,
#  4.9895,
#  4.98225,
#  4.98175,
#  4.98075,
#  5.00775,
#  4.96225,
#  5.00075,
#  5.01425,
#  4.971,
#  4.959,
#  4.99525,
#  5.0095,
#  4.99275,
#  4.95925,
#  4.9625,
#  4.9855,
#  5.00675,
#  4.988,
#  5.00675,
#  5.0075,
#  4.994]

# %%
sns.displot(sample_mean, kind="kde")
